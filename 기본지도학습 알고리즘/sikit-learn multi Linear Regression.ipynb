# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import pandas as pd

# %%
boston_dataset = load_boston()

# %%
print(boston_dataset.DESCR)

# %%
boston_dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
boston_dataset.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
X = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y = pd.DataFrame(boston_dataset.target , columns = ['MEDV'])

# %%
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2 , random_state= 5)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404, 1)
# (102, 1)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-1.30799852e-01,  4.94030235e-02,  1.09535045e-03,
#          2.70536624e+00, -1.59570504e+01,  3.41397332e+00,
#          1.11887670e-03, -1.49308124e+00,  3.64422378e-01,
#         -1.31718155e-02, -9.52369666e-01,  1.17492092e-02,
#         -5.94076089e-01]])

# %%
model.intercept_
# Out:
# array([37.91248701])

# %%
y_test_prediction = model.predict(X_test)
y_test_prediction

# %%
mean_squared_error(y_test, y_test_prediction) ** 0.5
# Out:
# 4.568292042303218

# %% [markdown]
# 실습과제
# 이번 과제에서는 scikit-learn 라이브러리에 있는 또 다른 데이터 셋인 당뇨병 수치 데이터를 이용해서 선형 모델을 학습시켜보겠습니다.
#
# 당뇨병 데이터 셋을 가지고 와서 각각 입력 변수와 목표 변수를 dataframe으로 바꾸는 코드까지는 이미 작성돼 있는데요. 배웠던 것처럼 여기서부터 한 번
#
# 데이터를 training/test 셋으로 나누고
# 선형 회귀 모델을 학습시키고
# 학습시킨 데이터를 이용해서 예측을 해보세요!
# (과제를 하기 전 꼭 print(diabetes_dataset.DESCR)을 써서 데이터 셋 내용을 살펴보세요!)
#
# 조건
# train_test_split 함수의 옵셔널 파라미터는 test_size=0.2, random_state=5 이렇게 설정해 주세요.
# testing set의 예측 값들은 꼭 변수 y_test_predict에 저장해 주세요.
# 정답 확인은 모델의 성능으로 합니다. (템플렛 가장 아래 줄에 출력 코드 있음)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error 
import pandas as pd 

diabetes_dataset = datasets.load_diabetes() #데이터셋 가져오기
X = pd.DataFrame(diabetes_dataset.data, columns = diabetes_dataset.feature_names) # feature_names은 데이터의 feature 값 
y = pd.DataFrame(diabetes_dataset.target , columns = ['diabetes'] ) # target 값 

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state = 5) #data들을 testset과 trainset으로 분리 
model = LinearRegression() # 모델 만들어주고 
model.fit(X_train, y_train) #train set으로 훈련 시켜주고

y_test_predict = model.predict(X_test) # test셋으로 예측 값 

mse = mean_squared_error(y_test,y_test_predict) # target - 예측값 으로 인한 오차 제곱 평균 

mse ** 0.5 #평균 제곱근 오차
# Out:
# 54.60389611984442
